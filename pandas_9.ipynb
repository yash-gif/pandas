# %% [markdown]
# # handling missing values in part 2

# %%
import pandas as pd

# %%
df = pd.read_csv("E:\\New folder (4)\\Book1.csv")
df
# Out:
#    Student ID Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001  Yes      10          2           9           0          5
# 1        1002  Yes      10          6           8           2          0
# 2        1003  Yes      10          3           8           2          4
# 3        1004  Yes      11          0          10           1          5
# 4        1005  Yes      11          4           7           2          0
# 5        1006  Yes      11         10           7           0          0
# 6        1007  Yes      12          4           6           0          0
# 7        1008   No      12         10           6           2          0
# 8        1009  Yes      12          2           8           2          4
# 9        1010   No      12          6           9           1          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90
# 8          60
# ...

# %%
df.isnull() # for finding null values in dataframe .
# Out:
#    Student ID   Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0       False  False   False      False       False       False      False
# 1       False  False   False      False       False       False      False
# 2       False  False   False      False       False       False      False
# 3       False  False   False      False       False       False      False
# 4       False  False   False      False       False       False      False
# 5       False  False   False      False       False       False      False
# 6       False  False   False      False       False       False      False
# 7       False  False   False      False       False       False      False
# 8       False  False   False      False       False       False      False
# 9       False  False   False      False       False       False      False
#
#    percentage
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# ...

# %%
df.isnull()
# Out:
#    Student ID   Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0       False  False   False      False       False       False      False
# 1       False  False   False      False       False       False      False
# 2       False  False   False      False       False       False      False
# 3       False  False   False      False       False       False      False
# 4       False  False   False      False       False       False      False
# 5       False  False   False      False       False       False      False
# 6       False  False   False      False       False       False      False
# 7       False  False   False      False       False       False      False
# 8       False  False   False      False       False       False      False
# 9       False  False   False      False       False       False      False
#
#    percentage
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# ...

# %%
df = pd.read_csv("E:\\New folder (4)\\Book1.csv")
df
# Out:
#    Student ID Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001  Yes      10          2           9           0          5
# 1        1002  Yes      10          6           8           2          0
# 2        1003  Yes      10          3           8           2          4
# 3        1004  Yes      11          0          10           1          5
# 4        1005  Yes      11          4           7           2          0
# 5        1006  Yes      11         10           7           0          0
# 6        1007  NaN      12          4           6           0          0
# 7        1008   No      12         10           6           2          0
# 8        1009  Yes      12          2           8           2          4
# 9        1010   No      12          6           9           1          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90
# 8          60
# ...

# %%
df.isnull(
)
# Out:
#    Student ID   Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0       False  False   False      False       False       False      False
# 1       False  False   False      False       False       False      False
# 2       False  False   False      False       False       False      False
# 3       False  False   False      False       False       False      False
# 4       False  False   False      False       False       False      False
# 5       False  False   False      False       False       False      False
# 6       False   True   False      False       False       False      False
# 7       False  False   False      False       False       False      False
# 8       False  False   False      False       False       False      False
# 9       False  False   False      False       False       False      False
#
#    percentage
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# ...

# %%
df.isnull().sum() # gives how many values in the dataset:
# Out:
# Student ID    0
# Date          1
# Class         0
# Study hrs     0
# sleeping h    0
# social mex    0
# mobile Ga     0
# percentage    0
# dtype: int64

# %%
df.isnull().sum().sum() # to find ttal null values:
# Out:
# 1

# %%
df = pd.read_csv("E:\\New folder (4)\\Book1.csv")
df
# Out:
#    Student ID Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001  Yes      10          2           9           0          5
# 1        1002  Yes      10          6           8           2          0
# 2        1003  Yes      10          3           8           2          4
# 3        1004  Yes      11          0          10           1          5
# 4        1005  Yes      11          4           7           2          0
# 5        1006  Yes      11         10           7           0          0
# 6        1007  NaN      12          4           6           0          0
# 7        1008   No      12         10           6           2          0
# 8        1009  Yes      12          2           8           2          4
# 9        1010   No      12          6           9           1          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90
# 8          60
# ...

# %%
df.notnull()
# Out:
#    Student ID   Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        True   True    True       True        True        True       True
# 1        True   True    True       True        True        True       True
# 2        True   True    True       True        True        True       True
# 3        True   True    True       True        True        True       True
# 4        True   True    True       True        True        True       True
# 5        True   True    True       True        True        True       True
# 6        True  False    True       True        True        True       True
# 7        True   True    True       True        True        True       True
# 8        True   True    True       True        True        True       True
# 9        True   True    True       True        True        True       True
#
#    percentage
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# ...

# %%
df.notnull().sum()
# Out:
# Student ID    10
# Date           9
# Class         10
# Study hrs     10
# sleeping h    10
# social mex    10
# mobile Ga     10
# percentage    10
# dtype: int64

# %%
df.notnull().sum().sum()
# Out:
# 79

# %%
# series:

# %%
import numpy as np
sr = pd.Series([1,2,3,np.nan,np.NAN])
sr.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# dtype: bool

# %%
sr.isnull().sum()
# Out:
# 2

# %%
sr.notnull()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
sr.notnull().sum()
# Out:
# 3
