# %%
import pandas as pd

# %%
# what is pandas replace function ?
# values to the dataframe are replaced with other values dynamically:
# Syntax : Dataframe.replace()

# parameters : to-replace , limit , value , regex , inplace , method

# %%
df = pd.read_csv("E:\\New folder (4)\\Book2.csv")
df
# Out:
#    ID     Name           Companies   Profit Growth
# 0   1  lamtone         IT Services    14124    30%
# 1   2     yash  Financial Services      424    20%
# 2   3    aadya              Health    41412     7%
# 3   4    yeshi         IT Services  4124124    NaN
# 4   5    rahul                 NaN   124124    21%

# %%
df.replace(to_replace = "IT Services" , value = "Data Services")
# Out:
#    ID     Name           Companies   Profit Growth
# 0   1  lamtone       Data Services    14124    30%
# 1   2     yash  Financial Services      424    20%
# 2   3    aadya              Health    41412     7%
# 3   4    yeshi       Data Services  4124124    NaN
# 4   5    rahul                 NaN   124124    21%

# %%
df.replace( "IT Services" ,  "Data Services")
# Out:
#    ID     Name           Companies   Profit Growth
# 0   1  lamtone       Data Services    14124    30%
# 1   2     yash  Financial Services      424    20%
# 2   3    aadya              Health    41412     7%
# 3   4    yeshi       Data Services  4124124    NaN
# 4   5    rahul                 NaN   124124    21%

# %%
df.replace(5,12)
# Out:
#    ID     Name           Companies   Profit Growth
# 0   1  lamtone         IT Services    14124    30%
# 1   2     yash  Financial Services      424    20%
# 2   3    aadya              Health    41412     7%
# 3   4    yeshi         IT Services  4124124    NaN
# 4  12    rahul                 NaN   124124    21%

# %%
df.replace([1,2,3,4,5],0)
# Out:
#    ID     Name           Companies   Profit Growth
# 0   0  lamtone         IT Services    14124    30%
# 1   0     yash  Financial Services      424    20%
# 2   0    aadya              Health    41412     7%
# 3   0    yeshi         IT Services  4124124    NaN
# 4   0    rahul                 NaN   124124    21%

# %%
df
# Out:
#    ID     Name           Companies   Profit Growth
# 0   1  lamtone         IT Services    14124    30%
# 1   2     yash  Financial Services      424    20%
# 2   3    aadya              Health    41412     7%
# 3   4    yeshi         IT Services  4124124    NaN
# 4   5    rahul                 NaN   124124    21%

# %%
df.replace([1,2,3,4,5],[7,7,8,8,9])
# Out:
#    ID     Name           Companies   Profit Growth
# 0   7  lamtone         IT Services    14124    30%
# 1   7     yash  Financial Services      424    20%
# 2   8    aadya              Health    41412     7%
# 3   8    yeshi         IT Services  4124124    NaN
# 4   9    rahul                 NaN   124124    21%

# %%
df
# Out:
#             date     location  new_cases  new_deaths  total_cases  \
# 0     2020-02-25  Afghanistan        NaN         NaN            1
# 1     2020-02-26  Afghanistan        0.0         NaN            1
# 2     2020-02-27  Afghanistan        0.0         NaN            1
# 3     2020-02-28  Afghanistan        0.0         NaN            1
# 4     2020-02-29  Afghanistan        0.0         NaN            1
# ...          ...          ...        ...         ...          ...
# 2862  2020-03-13        World     7488.0       338.0       132758
# 2863  2020-03-14        World     9761.0       433.0       142534
# 2864  2020-03-15        World    10967.0       343.0       153517
# 2865  2020-03-16        World    13971.0       855.0       167506
# 2866  2020-03-17        World    11594.0       819.0       179112
#
#       total_deaths
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 2862        4956.0
# ...

# %%
df = pd.read_csv("E:\\New folder (4)\\Book2.csv")
df
# Out:
#    ID     Name           Companies   Profit Growth
# 0   1  lamtone         IT Services    14124    30%
# 1   2     yash  Financial Services      424    20%
# 2   3    aadya              Health    41412     7%
# 3   4    yeshi         IT Services  4124124    NaN
# 4   5    rahul                 NaN   124124    21%

# %%
df.replace({"Companies":"Health"},"none")
# Out:
#    ID     Name           Companies   Profit Growth
# 0   1  lamtone         IT Services    14124    30%
# 1   2     yash  Financial Services      424    20%
# 2   3    aadya                none    41412     7%
# 3   4    yeshi         IT Services  4124124    NaN
# 4   5    rahul                 NaN   124124    21%

# %%
df.replace("[A-Za-z]",0)
# Out:
#    ID     Name           Companies   Profit Growth
# 0   1  lamtone         IT Services    14124    30%
# 1   2     yash  Financial Services      424    20%
# 2   3    aadya              Health    41412     7%
# 3   4    yeshi         IT Services  4124124    NaN
# 4   5    rahul                 NaN   124124    21%

# %%
df.replace("[A-Za-z]",0 , regex = True) # regex used to detect patterns:
# Out:
#    ID  Name  Companies   Profit Growth
# 0   1     0        0.0    14124    30%
# 1   2     0        0.0      424    20%
# 2   3     0        0.0    41412     7%
# 3   4     0        0.0  4124124    NaN
# 4   5     0        NaN   124124    21%

# %%
df
# Out:
#    ID     Name           Companies   Profit Growth
# 0   1  lamtone         IT Services    14124    30%
# 1   2     yash  Financial Services      424    20%
# 2   3    aadya              Health    41412     7%
# 3   4    yeshi         IT Services  4124124    NaN
# 4   5    rahul                 NaN   124124    21%

# %%
df.replace({"Name":"[A-Za-z]"},0,regex=True)
# Out:
#    ID  Name           Companies   Profit Growth
# 0   1     0         IT Services    14124    30%
# 1   2     0  Financial Services      424    20%
# 2   3     0              Health    41412     7%
# 3   4     0         IT Services  4124124    NaN
# 4   5     0                 NaN   124124    21%

# %%
df
# Out:
#    ID     Name           Companies   Profit Growth
# 0   1  lamtone         IT Services    14124    30%
# 1   2     yash  Financial Services      424    20%
# 2   3    aadya              Health    41412     7%
# 3   4    yeshi         IT Services  4124124    NaN
# 4   5    rahul                 NaN   124124    21%

# %%
df.replace("Health",method="ffill")
# Out:
#    ID     Name           Companies   Profit Growth
# 0   1  lamtone         IT Services    14124    30%
# 1   2     yash  Financial Services      424    20%
# 2   3    aadya  Financial Services    41412     7%
# 3   4    yeshi         IT Services  4124124    NaN
# 4   5    rahul                 NaN   124124    21%

# %%
df.replace("Health",method="bfill",limit = 1)
# Out:
#    ID     Name           Companies   Profit Growth
# 0   1  lamtone         IT Services    14124    30%
# 1   2     yash  Financial Services      424    20%
# 2   3    aadya         IT Services    41412     7%
# 3   4    yeshi         IT Services  4124124    NaN
# 4   5    rahul                 NaN   124124    21%

# %%
df
# Out:
#    ID     Name           Companies   Profit Growth
# 0   1  lamtone         IT Services    14124    30%
# 1   2     yash  Financial Services      424    20%
# 2   3    aadya              Health    41412     7%
# 3   4    yeshi         IT Services  4124124    NaN
# 4   5    rahul                 NaN   124124    21%

# %%
df.replace("Health",method="ffill",inplace = True)
df
# Out:
#    ID     Name           Companies   Profit Growth
# 0   2  lamtone         IT Services    14124    30%
# 1   2     yash  Financial Services      424    20%
# 2   3    aadya              Health    41412     7%
# 3   4    yeshi         IT Services  4124124    NaN
# 4   5    rahul                 NaN   124124    21%

# %%
df
# Out:
#    ID     Name           Companies   Profit Growth
# 0   2  lamtone         IT Services    14124    30%
# 1   2     yash  Financial Services      424    20%
# 2   3    aadya              Health    41412     7%
# 3   4    yeshi         IT Services  4124124    NaN
# 4   5    rahul                 NaN   124124    21%
