# %%
import pandas as pd

# %%
# pandas interpolate: pandas interpolate() function is basically used to fill NaN values in datframe or series.
# very powerful function
# uses various interpolation techniques

# syntax: DataFrame.interpolate(), Series.interpolate()
# parameters : method , inplace , axis , limit_direction , limit , limit_area.

# %%
 df = pd.read_csv("E:\\New folder (4)\\Book1.csv")
df
# Out:
#    Student ID Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001  Yes      10          2           9           0          5
# 1        1002  Yes      10          6           8           2          0
# 2        1003  Yes      10          3           8           2          4
# 3        1004  Yes      11          0          10           1          5
# 4        1005  Yes      11          4           7           2          0
# 5        1006  Yes      11         10           7           0          0
# 6        1007  NaN      12          4           6           0          0
# 7        1008   No      12         10           6           2          0
# 8        1009  Yes      12          2           8           2          4
# 9        1010   No      12          6           9           1          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90
# 8          60
# ...

# %%
df.interpolate()# guess missing numeric vakues:
# Out:
#    Student ID Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001  Yes      10          2           9           0          5
# 1        1002  Yes      10          6           8           2          0
# 2        1003  Yes      10          3           8           2          4
# 3        1004  Yes      11          0          10           1          5
# 4        1005  Yes      11          4           7           2          0
# 5        1006  Yes      11         10           7           0          0
# 6        1007  NaN      12          4           6           0          0
# 7        1008   No      12         10           6           2          0
# 8        1009  Yes      12          2           8           2          4
# 9        1010   No      12          6           9           1          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90
# 8          60
# ...

# %%
df.interpolate(method = "linear")
# Out:
#    Student ID Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001  Yes      10          2           9           0          5
# 1        1002  Yes      10          6           8           2          0
# 2        1003  Yes      10          3           8           2          4
# 3        1004  Yes      11          0          10           1          5
# 4        1005  Yes      11          4           7           2          0
# 5        1006  Yes      11         10           7           0          0
# 6        1007  NaN      12          4           6           0          0
# 7        1008   No      12         10           6           2          0
# 8        1009  Yes      12          2           8           2          4
# 9        1010   No      12          6           9           1          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90
# 8          60
# ...

# %%
df.interpolate(method = "time")# fills missing values according to time
# Out:
#    Student ID Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001  Yes      10          2           9           0          5
# 1        1002  Yes      10          6           8           2          0
# 2        1003  Yes      10          3           8           2          4
# 3        1004  Yes      11          0          10           1          5
# 4        1005  Yes      11          4           7           2          0
# 5        1006  Yes      11         10           7           0          0
# 6        1007  NaN      12          4           6           0          0
# 7        1008   No      12         10           6           2          0
# 8        1009  Yes      12          2           8           2          4
# 9        1010   No      12          6           9           1          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90
# 8          60
# ...

# %%
type(df.Date[0])
# Out:
# str

# %%
 df = pd.read_csv("E:\\New folder (4)\\Book1.csv",parse_dates = ["Date"])# change type of date into date-time datatype: 
df
# Out:
#    Student ID Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001  Yes      10          2           9           0          5
# 1        1002  Yes      10          6           8           2          0
# 2        1003  Yes      10          3           8           2          4
# 3        1004  Yes      11          0          10           1          5
# 4        1005  Yes      11          4           7           2          0
# 5        1006  Yes      11         10           7           0          0
# 6        1007  NaN      12          4           6           0          0
# 7        1008   No      12         10           6           2          0
# 8        1009  Yes      12          2           8           2          4
# 9        1010   No      12          6           9           1          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90
# 8          60
# ...

# %%
type(df.Date[0])
# Out:
# str

# %%
df.interpolate(method = "index") # fills null values according to what is index : and interpolate function works on only integers
# Out:
#    Student ID Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001  Yes      10          2           9           0          5
# 1        1002  Yes      10          6           8           2          0
# 2        1003  Yes      10          3           8           2          4
# 3        1004  Yes      11          0          10           1          5
# 4        1005  Yes      11          4           7           2          0
# 5        1006  Yes      11         10           7           0          0
# 6        1007  NaN      12          4           6           0          0
# 7        1008   No      12         10           6           2          0
# 8        1009  Yes      12          2           8           2          4
# 9        1010   No      12          6           9           1          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90
# 8          60
# ...

# %%
 df = pd.read_csv("E:\\New folder (4)\\Book1.csv" , index_col = "Student ID")# change type of date into time 
df
# Out:
#            Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# Student ID
# 1001        Yes      10          2           9           0          5
# 1002        Yes      10          6           8           2          0
# 1003        Yes      10          3           8           2          4
# 1004        Yes      11          0          10           1          5
# 1005        Yes      11          4           7           2          0
# 1006        Yes      11         10           7           0          0
# 1007        NaN      12          4           6           0          0
# 1008         No      12         10           6           2          0
# 1009        Yes      12          2           8           2          4
# 1010         No      12          6           9           1          0
#
#             percentage
# Student ID
# 1001                50
# 1002                80
# 1003                60
# 1004                45
# 1005                75
# 1006                96
# ...

# %%
df.interpolate(method = "index")
# Out:
#            Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# Student ID
# 1001        Yes      10          2           9           0          5
# 1002        Yes      10          6           8           2          0
# 1003        Yes      10          3           8           2          4
# 1004        Yes      11          0          10           1          5
# 1005        Yes      11          4           7           2          0
# 1006        Yes      11         10           7           0          0
# 1007        NaN      12          4           6           0          0
# 1008         No      12         10           6           2          0
# 1009        Yes      12          2           8           2          4
# 1010         No      12          6           9           1          0
#
#             percentage
# Student ID
# 1001                50
# 1002                80
# 1003                60
# 1004                45
# 1005                75
# 1006                96
# ...

# %%
df
# Out:
#            Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# Student ID
# 1001        Yes      10          2           9           0          5
# 1002        Yes      10          6           8           2          0
# 1003        Yes      10          3           8           2          4
# 1004        Yes      11          0          10           1          5
# 1005        Yes      11          4           7           2          0
# 1006        Yes      11         10           7           0          0
# 1007        NaN      12          4           6           0          0
# 1008         No      12         10           6           2          0
# 1009        Yes      12          2           8           2          4
# 1010         No      12          6           9           1          0
#
#             percentage
# Student ID
# 1001                50
# 1002                80
# 1003                60
# 1004                45
# 1005                75
# 1006                96
# ...

# %%
df
# Out:
#            Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# Student ID
# 1001        Yes      10          2           9           0          5
# 1002        Yes      10          6           8           2          0
# 1003        Yes      10          3           8           2          4
# 1004        Yes      11          0          10           1          5
# 1005        Yes      11          4           7           2          0
# 1006        Yes      11         10           7           0          0
# 1007        NaN      12          4           6           0          0
# 1008         No      12         10           6           2          0
# 1009        Yes      12          2           8           2          4
# 1010         No      12          6           9           1          0
#
#             percentage
# Student ID
# 1001                50
# 1002                80
# 1003                60
# 1004                45
# 1005                75
# 1006                96
# ...

# %%
df
# Out:
#            Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# Student ID
# 1001        Yes      10          2           9           0          5
# 1002        Yes      10          6           8           2          0
# 1003        Yes      10          3           8           2          4
# 1004        Yes      11          0          10           1          5
# 1005        Yes      11          4           7           2          0
# 1006        Yes      11         10           7           0          0
# 1007        NaN      12          4           6           0          0
# 1008         No      12         10           6           2          0
# 1009        Yes      12          2           8           2          4
# 1010         No      12          6           9           1          0
#
#             percentage
# Student ID
# 1001                50
# 1002                80
# 1003                60
# 1004                45
# 1005                75
# 1006                96
# ...

# %%
 df = pd.read_csv("E:\\New folder (4)\\Book1.csv")
df
# Out:
#    Student ID Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001  Yes      10        2.0           9           0          5
# 1        1002  Yes      10        6.0           8           2          0
# 2        1003  Yes      10        3.0           8           2          4
# 3        1004  Yes      11        0.0          10           1          5
# 4        1005  Yes      11        NaN           7           2          0
# 5        1006  Yes      11       10.0           7           0          0
# 6        1007  NaN      12        NaN           6           0          0
# 7        1008   No      12        NaN           6           2          0
# 8        1009  Yes      12        2.0           8           2          4
# 9        1010   No      12        6.0           9           1          0
#
#    percentage
# 0        50.0
# 1        80.0
# 2        60.0
# 3        45.0
# 4         NaN
# 5        96.0
# 6        80.0
# 7         NaN
# 8        60.0
# ...

# %%
df.interpolate()
# Out:
#    Student ID Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001  Yes      10   2.000000           9           0          5
# 1        1002  Yes      10   6.000000           8           2          0
# 2        1003  Yes      10   3.000000           8           2          4
# 3        1004  Yes      11   0.000000          10           1          5
# 4        1005  Yes      11   5.000000           7           2          0
# 5        1006  Yes      11  10.000000           7           0          0
# 6        1007  NaN      12   7.333333           6           0          0
# 7        1008   No      12   4.666667           6           2          0
# 8        1009  Yes      12   2.000000           8           2          4
# 9        1010   No      12   6.000000           9           1          0
#
#    percentage
# 0        50.0
# 1        80.0
# 2        60.0
# 3        45.0
# 4        70.5
# 5        96.0
# 6        80.0
# 7        70.0
# 8        60.0
# ...

# %%
 df = pd.read_csv("E:\\New folder (4)\\Book1.csv",index_col = "Student ID")
df
# Out:
#            Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# Student ID
# 1001        Yes      10        2.0           9           0          5
# 1002        Yes      10        6.0           8           2          0
# 1003        Yes      10        3.0           8           2          4
# 1004        Yes      11        0.0          10           1          5
# 1005        Yes      11        NaN           7           2          0
# 1006        Yes      11       10.0           7           0          0
# 1007        NaN      12        NaN           6           0          0
# 1008         No      12        NaN           6           2          0
# 1009        Yes      12        2.0           8           2          4
# 1010         No      12        6.0           9           1          0
#
#             percentage
# Student ID
# 1001              50.0
# 1002              80.0
# 1003              60.0
# 1004              45.0
# 1005               NaN
# 1006              96.0
# ...

# %%
df.interpolate(method = "index")
# Out:
#            Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# Student ID
# 1001        Yes      10   2.000000           9           0          5
# 1002        Yes      10   6.000000           8           2          0
# 1003        Yes      10   3.000000           8           2          4
# 1004        Yes      11   0.000000          10           1          5
# 1005        Yes      11   5.000000           7           2          0
# 1006        Yes      11  10.000000           7           0          0
# 1007        NaN      12   7.333333           6           0          0
# 1008         No      12   4.666667           6           2          0
# 1009        Yes      12   2.000000           8           2          4
# 1010         No      12   6.000000           9           1          0
#
#             percentage
# Student ID
# 1001              50.0
# 1002              80.0
# 1003              60.0
# 1004              45.0
# 1005              70.5
# 1006              96.0
# ...

# %%
df.interpolate(method = "nearest")
# Out:
#            Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# Student ID
# 1001        Yes      10        2.0           9           0          5
# 1002        Yes      10        6.0           8           2          0
# 1003        Yes      10        3.0           8           2          4
# 1004        Yes      11        0.0          10           1          5
# 1005        Yes      11        0.0           7           2          0
# 1006        Yes      11       10.0           7           0          0
# 1007        NaN      12       10.0           6           0          0
# 1008         No      12        2.0           6           2          0
# 1009        Yes      12        2.0           8           2          4
# 1010         No      12        6.0           9           1          0
#
#             percentage
# Student ID
# 1001              50.0
# 1002              80.0
# 1003              60.0
# 1004              45.0
# 1005              45.0
# 1006              96.0
# ...

# %%
df.interpolate(method = "polynomial" , order = 1)
# Out:
#            Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# Student ID
# 1001        Yes      10   2.000000           9           0          5
# 1002        Yes      10   6.000000           8           2          0
# 1003        Yes      10   3.000000           8           2          4
# 1004        Yes      11   0.000000          10           1          5
# 1005        Yes      11   5.000000           7           2          0
# 1006        Yes      11  10.000000           7           0          0
# 1007        NaN      12   7.333333           6           0          0
# 1008         No      12   4.666667           6           2          0
# 1009        Yes      12   2.000000           8           2          4
# 1010         No      12   6.000000           9           1          0
#
#             percentage
# Student ID
# 1001              50.0
# 1002              80.0
# 1003              60.0
# 1004              45.0
# 1005              70.5
# 1006              96.0
# ...

# %%
df.interpolate(method = "polynomial" , order = 2)
# Out:
#            Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# Student ID
# 1001        Yes      10   2.000000           9           0          5
# 1002        Yes      10   6.000000           8           2          0
# 1003        Yes      10   3.000000           8           2          4
# 1004        Yes      11   0.000000          10           1          5
# 1005        Yes      11   4.452352           7           2          0
# 1006        Yes      11  10.000000           7           0          0
# 1007        NaN      12   9.208344           6           0          0
# 1008         No      12   3.565481           6           2          0
# 1009        Yes      12   2.000000           8           2          4
# 1010         No      12   6.000000           9           1          0
#
#             percentage
# Student ID
# 1001         50.000000
# 1002         80.000000
# 1003         60.000000
# 1004         45.000000
# 1005         70.986345
# 1006         96.000000
# ...

# %%
df.interpolate(method = "spline",order = 2)
# Out:
#            Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# Student ID
# 1001        Yes      10   2.000000           9           0          5
# 1002        Yes      10   6.000000           8           2          0
# 1003        Yes      10   3.000000           8           2          4
# 1004        Yes      11   0.000000          10           1          5
# 1005        Yes      11   6.318461           7           2          0
# 1006        Yes      11  10.000000           7           0          0
# 1007        NaN      12   8.894970           6           0          0
# 1008         No      12   6.980162           6           2          0
# 1009        Yes      12   2.000000           8           2          4
# 1010         No      12   6.000000           9           1          0
#
#             percentage
# Student ID
# 1001         50.000000
# 1002         80.000000
# 1003         60.000000
# 1004         45.000000
# 1005         70.407706
# 1006         96.000000
# ...

# %%
# if we works on time series than use of quadratic parameter is best.
# if we want to visualize data then use of alima parameter is best.
