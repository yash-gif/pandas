# %%
import pandas as pd

# %%
df = pd.read_csv("E:\\New folder (4)\\Book1.csv")
df
# Out:
#    Student ID  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001      10          2           9           0          5
# 1        1002      10          6           8           2          0
# 2        1003      10          3           8           2          4
# 3        1004      11          0          10           1          5
# 4        1005      11          4           7           2          0
# 5        1006      11         10           7           0          0
# 6        1007      12          4           6           0          0
# 7        1008      12         10           6           2          0
# 8        1009      12          2           8           2          4
# 9        1010      12          6           9           1          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90
# 8          60
# 9          85

# %%
df.head() # this function print top 5 rows
# Out:
#    Student ID  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001      10          2           9           0          5
# 1        1002      10          6           8           2          0
# 2        1003      10          3           8           2          4
# 3        1004      11          0          10           1          5
# 4        1005      11          4           7           2          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75

# %%
df.head(1)
# Out:
#    Student ID  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001      10          2           9           0          5
#
#    percentage
# 0          50

# %%
df.head(8)
# Out:
#    Student ID  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001      10          2           9           0          5
# 1        1002      10          6           8           2          0
# 2        1003      10          3           8           2          4
# 3        1004      11          0          10           1          5
# 4        1005      11          4           7           2          0
# 5        1006      11         10           7           0          0
# 6        1007      12          4           6           0          0
# 7        1008      12         10           6           2          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90

# %%
# head method is useful in quick testing of data , specially if you want to know your data type is correct or not.

# %%
df.tail() # return 5 rows from bottom
# Out:
#    Student ID  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 5        1006      11         10           7           0          0
# 6        1007      12          4           6           0          0
# 7        1008      12         10           6           2          0
# 8        1009      12          2           8           2          4
# 9        1010      12          6           9           1          0
#
#    percentage
# 5          96
# 6          80
# 7          90
# 8          60
# 9          85

# %%
df.tail(2)
# Out:
#    Student ID  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 8        1009      12          2           8           2          4
# 9        1010      12          6           9           1          0
#
#    percentage
# 8          60
# 9          85

# %%
df.tail(7)
# Out:
#    Student ID  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 3        1004      11          0          10           1          5
# 4        1005      11          4           7           2          0
# 5        1006      11         10           7           0          0
# 6        1007      12          4           6           0          0
# 7        1008      12         10           6           2          0
# 8        1009      12          2           8           2          4
# 9        1010      12          6           9           1          0
#
#    percentage
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90
# 8          60
# 9          85

# %%
# in pandas tail method is used to quickly verify the data .

# %%
# parameters of read_csv methods:

# %%
df = pd.read_csv("E:\\New folder (4)\\Book1.csv" , dtype = {"Class":"float64"})
df
# Out:
#    Student ID  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001      10          2           9           0          5
# 1        1002      10          6           8           2          0
# 2        1003      10          3           8           2          4
# 3        1004      11          0          10           1          5
# 4        1005      11          4           7           2          0
# 5        1006      11         10           7           0          0
# 6        1007      12          4           6           0          0
# 7        1008      12         10           6           2          0
# 8        1009      12          2           8           2          4
# 9        1010      12          6           9           1          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90
# 8          60
# 9          85

# %%
df = pd.read_csv("E:\\New folder (4)\\Book1.csv" , dtype = {"Class":"float64", "social mex":"float64"})
df
# Out:
#    Student ID  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001      10          2           9         0.0          5
# 1        1002      10          6           8         2.0          0
# 2        1003      10          3           8         2.0          4
# 3        1004      11          0          10         1.0          5
# 4        1005      11          4           7         2.0          0
# 5        1006      11         10           7         0.0          0
# 6        1007      12          4           6         0.0          0
# 7        1008      12         10           6         2.0          0
# 8        1009      12          2           8         2.0          4
# 9        1010      12          6           9         1.0          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90
# 8          60
# 9          85

# %%
df = pd.read_csv("E:\\New folder (4)\\Book1.csv")
df
# Out:
#    Student ID  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001      10          2           9           0          5
# 1        1002      10          6           8           2          0
# 2        1003      10          3           8           2          4
# 3        1004      11          0          10           1          5
# 4        1005      11          4           7           2          0
# 5        1006      11         10           7           0          0
# 6        1007      12          4           6           0          0
# 7        1008      12         10           6           2          0
# 8        1009      12          2           8           2          4
# 9        1010      12          6           9           1          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90
# 8          60
# 9          85

# %%
df = pd.read_csv("E:\\New folder (4)\\Book1.csv")
df
# Out:
#    Student ID Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001  Yes      10          2           9           0          5
# 1        1002  Yes      10          6           8           2          0
# 2        1003  Yes      10          3           8           2          4
# 3        1004  Yes      11          0          10           1          5
# 4        1005  Yes      11          4           7           2          0
# 5        1006  Yes      11         10           7           0          0
# 6        1007  Yes      12          4           6           0          0
# 7        1008  Yes      12         10           6           2          0
# 8        1009  Yes      12          2           8           2          4
# 9        1010  Yes      12          6           9           1          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90
# 8          60
# ...

# %%
df = pd.read_csv("E:\\New folder (4)\\Book1.csv",true_values = ["Yes"])
df
# Out:
#    Student ID  Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001  True      10          2           9           0          5
# 1        1002  True      10          6           8           2          0
# 2        1003  True      10          3           8           2          4
# 3        1004  True      11          0          10           1          5
# 4        1005  True      11          4           7           2          0
# 5        1006  True      11         10           7           0          0
# 6        1007  True      12          4           6           0          0
# 7        1008  True      12         10           6           2          0
# 8        1009  True      12          2           8           2          4
# 9        1010  True      12          6           9           1          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90
# ...

# %%
df = pd.read_csv("E:\\New folder (4)\\Book1.csv")
df
# Out:
#    Student ID Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001  Yes      10          2           9           0          5
# 1        1002  Yes      10          6           8           2          0
# 2        1003  Yes      10          3           8           2          4
# 3        1004  Yes      11          0          10           1          5
# 4        1005  Yes      11          4           7           2          0
# 5        1006  Yes      11         10           7           0          0
# 6        1007  Yes      12          4           6           0          0
# 7        1008   No      12         10           6           2          0
# 8        1009  Yes      12          2           8           2          4
# 9        1010   No      12          6           9           1          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90
# 8          60
# ...

# %%
df = pd.read_csv("E:\\New folder (4)\\Book1.csv",false_values = ["No"], true_values = ["Yes"])
df
# Out:
#    Student ID   Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001   True      10          2           9           0          5
# 1        1002   True      10          6           8           2          0
# 2        1003   True      10          3           8           2          4
# 3        1004   True      11          0          10           1          5
# 4        1005   True      11          4           7           2          0
# 5        1006   True      11         10           7           0          0
# 6        1007   True      12          4           6           0          0
# 7        1008  False      12         10           6           2          0
# 8        1009   True      12          2           8           2          4
# 9        1010  False      12          6           9           1          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90
# ...
