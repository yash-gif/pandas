# %%
import pandas as pd

# %%
df = pd.read_csv("E:\\New folder (4)\\Book1.csv")
df
# Out:
#    Student ID  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001      10          2           9           0          5
# 1        1002      10          6           8           2          0
# 2        1003      10          3           8           2          4
# 3        1004      11          0          10           1          5
# 4        1005      11          4           7           2          0
# 5        1006      11         10           7           0          0
# 6        1007      12          4           6           0          0
# 7        1008      12         10           6           2          0
# 8        1009      12          2           8           2          4
# 9        1010      12          6           9           1          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90
# 8          60
# 9          85

# %%
df = pd.read_csv("E:\\New folder (4)\\Book1.csv",header = 1)
df
# Out:
#    1001  10   2   9  0  5  50
# 0  1002  10   6   8  2  0  80
# 1  1003  10   3   8  2  4  60
# 2  1004  11   0  10  1  5  45
# 3  1005  11   4   7  2  0  75
# 4  1006  11  10   7  0  0  96
# 5  1007  12   4   6  0  0  80
# 6  1008  12  10   6  2  0  90
# 7  1009  12   2   8  2  4  60
# 8  1010  12   6   9  1  0  85

# %%
df = pd.read_csv("E:\\New folder (4)\\Book1.csv")
df
# Out:
#    Student ID  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001      10          2           9           0          5
# 1        1002      10          6           8           2          0
# 2        1003      10          3           8           2          4
# 3        1004      11          0          10           1          5
# 4        1005      11          4           7           2          0
# 5        1006      11         10           7           0          0
# 6        1007      12          4           6           0          0
# 7        1008      12         10           6           2          0
# 8        1009      12          2           8           2          4
# 9        1010      12          6           9           1          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90
# 8          60
# 9          85

# %%
df = pd.read_csv("E:\\New folder (4)\\Book1.csv", header = None)
df
# Out:
#              0       1          2           3           4          5  \
# 0   Student ID  Class   Study hrs  sleeping h  social mex  mobile Ga
# 1         1001      10          2           9           0          5
# 2         1002      10          6           8           2          0
# 3         1003      10          3           8           2          4
# 4         1004      11          0          10           1          5
# 5         1005      11          4           7           2          0
# 6         1006      11         10           7           0          0
# 7         1007      12          4           6           0          0
# 8         1008      12         10           6           2          0
# 9         1009      12          2           8           2          4
# 10        1010      12          6           9           1          0
#
#              6
# 0   percentage
# 1           50
# 2           80
# 3           60
# 4           45
# 5           75
# 6           96
# ...

# %%
df = pd.read_csv("E:\\New folder (4)\\Book1.csv")
df
# Out:
#    Student ID  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001      10          2           9           0          5
# 1        1002      10          6           8           2          0
# 2        1003      10          3           8           2          4
# 3        1004      11          0          10           1          5
# 4        1005      11          4           7           2          0
# 5        1006      11         10           7           0          0
# 6        1007      12          4           6           0          0
# 7        1008      12         10           6           2          0
# 8        1009      12          2           8           2          4
# 9        1010      12          6           9           1          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90
# 8          60
# 9          85

# %%
df = pd.read_csv("E:\\New folder (4)\\Book1.csv",header = None , prefix = "column")
df
# Out:
#        column0 column1    column2     column3     column4    column5  \
# 0   Student ID  Class   Study hrs  sleeping h  social mex  mobile Ga
# 1         1001      10          2           9           0          5
# 2         1002      10          6           8           2          0
# 3         1003      10          3           8           2          4
# 4         1004      11          0          10           1          5
# 5         1005      11          4           7           2          0
# 6         1006      11         10           7           0          0
# 7         1007      12          4           6           0          0
# 8         1008      12         10           6           2          0
# 9         1009      12          2           8           2          4
# 10        1010      12          6           9           1          0
#
#        column6
# 0   percentage
# 1           50
# 2           80
# 3           60
# 4           45
# 5           75
# 6           96
# ...

# %%
df = pd.read_csv("E:\\New folder (4)\\Book1.csv",names = ["a","b","c","d","e","f","g"])
df
# Out:
#              a       b          c           d           e          f  \
# 0   Student ID  Class   Study hrs  sleeping h  social mex  mobile Ga
# 1         1001      10          2           9           0          5
# 2         1002      10          6           8           2          0
# 3         1003      10          3           8           2          4
# 4         1004      11          0          10           1          5
# 5         1005      11          4           7           2          0
# 6         1006      11         10           7           0          0
# 7         1007      12          4           6           0          0
# 8         1008      12         10           6           2          0
# 9         1009      12          2           8           2          4
# 10        1010      12          6           9           1          0
#
#              g
# 0   percentage
# 1           50
# 2           80
# 3           60
# 4           45
# 5           75
# 6           96
# ...

# %%
df = pd.read_csv("E:\\New folder (4)\\Book1.csv")
df
# Out:
#    Student ID  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001      10          2           9           0          5
# 1        1002      10          6           8           2          0
# 2        1003      10          3           8           2          4
# 3        1004      11          0          10           1          5
# 4        1005      11          4           7           2          0
# 5        1006      11         10           7           0          0
# 6        1007      12          4           6           0          0
# 7        1008      12         10           6           2          0
# 8        1009      12          2           8           2          4
# 9        1010      12          6           9           1          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90
# 8          60
# 9          85
