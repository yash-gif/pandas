# %%
import pandas as pd # handling missing values in pandas:

# %%
df = pd.read_csv("E:\\New folder (4)\\Book1.csv")
df
# Out:
#    Student ID Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001  Yes      10          2           9           0          5
# 1        1002  Yes      10          6           8           2          0
# 2        1003  Yes      10          3           8           2          4
# 3        1004  Yes      11          0          10           1          5
# 4        1005  Yes      11          4           7           2          0
# 5        1006  Yes      11         10           7           0          0
# 6        1007  Yes      12          4           6           0          0
# 7        1008   No      12         10           6           2          0
# 8        1009  Yes      12          2           8           2          4
# 9        1010   No      12          6           9           1          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90
# 8          60
# ...

# %%
df = pd.read_csv("E:\\New folder (4)\\Book1.csv")
df
# Out:
#    Student ID Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001  Yes      10          2           9           0          5
# 1        1002  Yes      10          6           8           2          0
# 2        1003  Yes      10          3           8           2          4
# 3        1004  Yes      11          0          10           1          5
# 4        1005  Yes      11          4           7           2          0
# 5        1006  NaN      11         10           7           0          0
# 6        1007  NaN      12          4           6           0          0
# 7        1008   No      12         10           6           2          0
# 8        1009  Yes      12          2           8           2          4
# 9        1010   No      12          6           9           1          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90
# 8          60
# ...

# %%
df = pd.read_csv("E:\\New folder (4)\\Book1.csv",na_values = ["Yes" , "No"])# for considering any string as NaN
df
# Out:
#    Student ID  Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001   NaN      10          2           9           0          5
# 1        1002   NaN      10          6           8           2          0
# 2        1003   NaN      10          3           8           2          4
# 3        1004   NaN      11          0          10           1          5
# 4        1005   NaN      11          4           7           2          0
# 5        1006   NaN      11         10           7           0          0
# 6        1007   NaN      12          4           6           0          0
# 7        1008   NaN      12         10           6           2          0
# 8        1009   NaN      12          2           8           2          4
# 9        1010   NaN      12          6           9           1          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90
# ...

# %%
df = pd.read_csv("E:\\New folder (4)\\Book1.csv")
df
# Out:
#    Student ID Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001  Yes      10          2           9           0          5
# 1        1002  Yes      10          6           8           2          0
# 2        1003  Yes      10          3           8           2          4
# 3        1004  Yes      11          0          10           1          5
# 4        1005  Yes      11          4           7           2          0
# 5        1006  NaN      11         10           7           0          0
# 6        1007  NaN      12          4           6           0          0
# 7        1008   No      12         10           6           2          0
# 8        1009  Yes      12          2           8           2          4
# 9        1010   No      12          6           9           1          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90
# 8          60
# ...

# %%
df = pd.read_csv("E:\\New folder (4)\\Book1.csv" , na_values = {"Date":"No"})
df
# Out:
#    Student ID Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001  Yes      10          2           9           0          5
# 1        1002  Yes      10          6           8           2          0
# 2        1003  Yes      10          3           8           2          4
# 3        1004  Yes      11          0          10           1          5
# 4        1005  Yes      11          4           7           2          0
# 5        1006  NaN      11         10           7           0          0
# 6        1007  NaN      12          4           6           0          0
# 7        1008  NaN      12         10           6           2          0
# 8        1009  Yes      12          2           8           2          4
# 9        1010  NaN      12          6           9           1          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90
# 8          60
# ...

# %%
df = pd.read_csv("E:\\New folder (4)\\Book1.csv",na_values = "No")
df
# Out:
#    Student ID Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001  Yes      10          2           9           0          5
# 1        1002  Yes      10          6           8           2          0
# 2        1003  Yes      10          3           8           2          4
# 3        1004  Yes      11          0          10           1          5
# 4        1005  Yes      11          4           7           2          0
# 5        1006  NaN      11         10           7           0          0
# 6        1007  NaN      12          4           6           0          0
# 7        1008  NaN      12         10           6           2          0
# 8        1009  Yes      12          2           8           2          4
# 9        1010  NaN      12          6           9           1          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90
# 8          60
# ...

# %%
df = pd.read_csv("E:\\New folder (4)\\Book1.csv",keep_default_na = False)# does not condider default values as NaN:
df
# Out:
#    Student ID Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001  Yes      10          2           9           0          5
# 1        1002  Yes      10          6           8           2          0
# 2        1003  Yes      10          3           8           2          4
# 3        1004  Yes      11          0          10           1          5
# 4        1005  Yes      11          4           7           2          0
# 5        1006           11         10           7           0          0
# 6        1007           12          4           6           0          0
# 7        1008   No      12         10           6           2          0
# 8        1009  Yes      12          2           8           2          4
# 9        1010   No      12          6           9           1          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90
# 8          60
# ...

# %%
df = pd.read_csv("E:\\New folder (4)\\Book1.csv",keep_default_na = True)# treet those as values as default:
df
# Out:
#    Student ID Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001  Yes      10          2           9           0          5
# 1        1002  Yes      10          6           8           2          0
# 2        1003  Yes      10          3           8           2          4
# 3        1004  Yes      11          0          10           1          5
# 4        1005  Yes      11          4           7           2          0
# 5        1006  NaN      11         10           7           0          0
# 6        1007  NaN      12          4           6           0          0
# 7        1008   No      12         10           6           2          0
# 8        1009  Yes      12          2           8           2          4
# 9        1010   No      12          6           9           1          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90
# 8          60
# ...

# %%
#na_filter : it is used to find the missing values and interprete in the dataset:if there is no missing values in the datset
# then by using this parameter we reduce the parsing speed od our data . data parsing means syntax analysis means process of 
# analysing the string in the dataset. so by using this we can boost our performance.

# %%
df = pd.read_csv("E:\\New folder (4)\\Book1.csv",na_filter = False) 
df
# Out:
#    Student ID Date  Class   Study hrs  sleeping h  social mex  mobile Ga  \
# 0        1001  Yes      10          2           9           0          5
# 1        1002  Yes      10          6           8           2          0
# 2        1003  Yes      10          3           8           2          4
# 3        1004  Yes      11          0          10           1          5
# 4        1005  Yes      11          4           7           2          0
# 5        1006  Yes      11         10           7           0          0
# 6        1007  Yes      12          4           6           0          0
# 7        1008   No      12         10           6           2          0
# 8        1009  Yes      12          2           8           2          4
# 9        1010   No      12          6           9           1          0
#
#    percentage
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# 7          90
# 8          60
# ...
